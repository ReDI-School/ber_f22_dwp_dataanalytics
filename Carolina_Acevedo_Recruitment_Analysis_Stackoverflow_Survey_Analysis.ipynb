# %% [markdown]
# # “How to recruit Data Scientists?” - Recruitment Analysis

# %% [markdown]
# ## **Description:**
#
# You are working for a major tech company in Berlin as a Junior Data Analyst. The tech company wants to grow and hire for their new Data Science team. The HR department of the company asks you to create an analysis on how to recruit for the new data science team.
#
# You take the Stackoverflow Survey to analyze the data science market.
#
# The company wants to recruit people who have Python and SQL skills.
#
# **Please answer the following questions:**
# - How many Data Analyst / Scientists are in the survey?
# - What profile do these Data Analyst / Scientist have? (Background, education, work experience)
# - What is the salary range for such Data Analysts / Scientists?
# - Please share any other insight you find that would be relevant for deciding how to recruit Data Analysts/Scientist.

# %% [markdown]
# ## Resources:
#
# * [About the Survey ](https://insights.stackoverflow.com/survey)

# %%
import requests, zipfile, io
import pandas as pd

# %%
# Link to Survey Data
zip_file_url = "https://info.stackoverflowsolutions.com/rs/719-EMH-566/images/stack-overflow-developer-survey-2022.zip"

# %%
# Download Survey Data into Google Colab
r = requests.get(zip_file_url)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall("/content")

# %%
# Load Survey Data
survey_results = pd.read_csv("/content/survey_results_public.csv")

# %%
survey_results.describe()
# Out:
#          ResponseId     CompTotal  VCHostingPersonal use  \
# count  73268.000000  3.842200e+04                    0.0
# mean   36634.500000  2.342434e+52                    NaN
# std    21150.794099  4.591478e+54                    NaN
# min        1.000000  0.000000e+00                    NaN
# 25%    18317.750000  3.000000e+04                    NaN
# 50%    36634.500000  7.750000e+04                    NaN
# 75%    54951.250000  1.540000e+05                    NaN
# max    73268.000000  9.000000e+56                    NaN
#
#        VCHostingProfessional use       WorkExp  ConvertedCompYearly
# count                        0.0  36769.000000         3.807100e+04
# mean                         NaN     10.242378         1.707613e+05
# std                          NaN      8.706850         7.814132e+05
# min                          NaN      0.000000         1.000000e+00
# 25%                          NaN      4.000000         3.583200e+04
# ...

# %%
survey_results
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                                      None of these
# 1               2                     I am a developer by profession
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 73263       73264                     I am a developer by profession
# 73264       73265                     I am a developer by profession
# 73265       73266  I am not primarily a developer, but I write co...
# 73266       73267                     I am a developer by profession
# 73267       73268  I used to be a developer by profession, but no...
#
#                                               Employment  \
# 0                                                    NaN
# ...

# %%
survey_results.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'BuyNewTool', 'Country', 'Currency',
#        'CompTotal', 'CompFreq', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysProfessional use',
#        'OpSysPersonal use', 'VersionControlSystem', 'VCInteraction',
#        'VCHostingPersonal use', 'VCHostingProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
# ...

# %%
survey_results['ConvertedCompYearly'].describe()
# Out:
# count    3.807100e+04
# mean     1.707613e+05
# std      7.814132e+05
# min      1.000000e+00
# 25%      3.583200e+04
# 50%      6.784500e+04
# 75%      1.200000e+05
# max      5.000000e+07
# Name: ConvertedCompYearly, dtype: float64

# %%
survey_results.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                                      None of these
# 1           2                     I am a developer by profession
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#             Employment                            RemoteWork  \
# 0                  NaN                                   NaN
# 1  Employed, full-time                          Fully remote
# 2  Employed, full-time  Hybrid (some remote, some in-person)
# 3  Employed, full-time                          Fully remote
# 4  Employed, full-time  Hybrid (some remote, some in-person)
#
#                            CodingActivities  \
# 0                                       NaN
# 1  Hobby;Contribute to open-source projects
# 2                                     Hobby
# ...

# %%
survey_results['MainBranch'].value_counts()
# Out:
# I am a developer by profession                                                   53507
# I am learning to code                                                             6309
# I am not primarily a developer, but I write code sometimes as part of my work     5794
# I code primarily as a hobby                                                       4865
# None of these                                                                     1497
# I used to be a developer by profession, but no longer am                          1296
# Name: MainBranch, dtype: int64

# %%
survey_results['DevType'].value_counts()
# Out:
# Developer, full-stack                                                                                                                                                                                                                                                                                                                                                                                                                  7142
# Developer, back-end                                                                                                                                                                                                                                                                                                                                                                                                                    5301
# ...

# %%
dfdatascientist = survey_results.loc[survey_results["DevType"] == "Data scientist or machine learning specialist"]

# %%
dfdatascientist.loc[dfdatascientist['LearnCodeCoursesCert'] == "Coursera"]
# Out:
#        ResponseId                                         MainBranch  \
# 1870         1871                     I am a developer by profession
# 6160         6161                     I am a developer by profession
# 6635         6636                     I am a developer by profession
# 6646         6647                     I am a developer by profession
# 7433         7434  I am not primarily a developer, but I write co...
# 8131         8132                     I am a developer by profession
# 12393       12394                     I am a developer by profession
# 12459       12460                     I am a developer by profession
# 13405       13406  I used to be a developer by profession, but no...
# 16922       16923                     I am a developer by profession
# 25635       25636                     I am a developer by profession
# 26512       26513                     I am a developer by profession
# 29086       29087                     I am a developer by profession
# ...

# %%
dfdatascientist.loc[dfdatascientist['LearnCodeCoursesCert'] == "Udemy"]
# Out:
#        ResponseId                                         MainBranch  \
# 4169         4170  I am not primarily a developer, but I write co...
# 4741         4742                     I am a developer by profession
# 5702         5703                     I am a developer by profession
# 6034         6035                     I am a developer by profession
# 8818         8819                     I am a developer by profession
# 14211       14212                     I am a developer by profession
# 14780       14781  I am not primarily a developer, but I write co...
# 18286       18287  I am not primarily a developer, but I write co...
# 19242       19243  I am not primarily a developer, but I write co...
# 29358       29359  I am not primarily a developer, but I write co...
# 31159       31160  I am not primarily a developer, but I write co...
# 37553       37554                     I am a developer by profession
# 39506       39507                     I am a developer by profession
# ...

# %%
dfdatascientist.loc[dfdatascientist['LearnCodeCoursesCert'] == "NaN"]
# Out:
# Empty DataFrame
# ...

# %%
dfdatascientist['LearnCodeCoursesCert'].value_counts()
# Out:
# Coursera                                                   37
# Coursera;Udemy                                             29
# Udemy                                                      22
# Other                                                      16
# Coursera;Udemy;Udacity                                     11
# Coursera;edX                                               11
# Coursera;Udemy;edX                                         11
# Coursera;edX;Udacity                                        8
# Udemy;Udacity                                               6
# Coursera;Udemy;Codecademy;edX                               6
# Coursera;Codecademy                                         6
# Coursera;Pluralsight                                        6
# Coursera;Udacity                                            5
# Coursera;Udemy;Codecademy                                   5
# Coursera;Other                                              4
# ...

# %%
dfdatascientist.loc[dfdatascientist['LearnCodeCoursesCert'] == "Udacity"]
# Out:
#        ResponseId                      MainBranch           Employment  \
# 33791       33792  I am a developer by profession  Employed, full-time
# 40245       40246  I am a developer by profession  Employed, full-time
# 55270       55271  I am a developer by profession  Employed, full-time
#
#                                  RemoteWork              CodingActivities  \
# 33791                        Full in-person  I don’t code outside of work
# 40245  Hybrid (some remote, some in-person)                         Hobby
# 55270  Hybrid (some remote, some in-person)       School or academic work
#
#                                                EdLevel  \
# 33791       Other doctoral degree (Ph.D., Ed.D., etc.)
# 40245  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 55270  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
#
#                                                LearnCode  \
# 33791  Other online resources (e.g., videos, blogs, f...
# ...

# %%
dfdatascientist['EdLevel'].value_counts()
# Out:
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       248
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          132
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             88
# Some college/university study without earning a degree                                 10
# Professional degree (JD, MD, etc.)                                                      9
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)      7
# Something else                                                                          2
# Associate degree (A.A., A.S., etc.)                                                     1
# Primary/elementary school                                                               1
# Name: EdLevel, dtype: int64

# %%
dfdatascientist['LanguageHaveWorkedWith'].value_counts()
# Out:
# Python                                   57
# Python;SQL                               47
# Python;R;SQL                             25
# Bash/Shell;Python                        19
# Bash/Shell;Python;SQL                    18
#                                          ..
# Objective-C;Python;Swift                  1
# JavaScript;Python;R;SAS;SQL               1
# Dart;HTML/CSS;JavaScript;Python;Swift     1
# Python;VBA                                1
# Java;Python;Scala;SQL                     1
# Name: LanguageHaveWorkedWith, Length: 232, dtype: int64

# %%
dfdatascientist['Employment'].value_counts()
# Out:
# Employed, full-time                                                                                                               412
# Independent contractor, freelancer, or self-employed                                                                               19
# Not employed, but looking for work                                                                                                 14
# Employed, part-time                                                                                                                11
# Student, full-time;Employed, part-time                                                                                              9
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                            9
# Employed, full-time;Student, part-time                                                                                              8
# ...

# %%
dfdatascientist['MentalHealth'].value_counts()
# Out:
# None of the above                                                                                                                                                                                                                                 363
# Prefer not to say                                                                                                                                                                                                                                  24
# I have an anxiety disorder                                                                                                                                                                                                                         17
# I have a concentration and/or memory disorder (e.g., ADHD, etc.)                                                                                                                                                                                   13
# ...

# %%
dfdatascientist['ConvertedCompYearly'].max()
# Out:
# 10000000.0

# %%
dfdatascientist['ConvertedCompYearly'].mean()
# Out:
# 186179.15204678362

# %%
survey_results.loc[survey_results["DevType"] == "Database administrator"].count()
# Out:
# ResponseId             48
# MainBranch             48
# Employment             48
# RemoteWork             47
# CodingActivities       47
#                        ..
# TrueFalse_2            24
# TrueFalse_3            24
# SurveyLength           48
# SurveyEase             48
# ConvertedCompYearly    22
# Length: 79, dtype: int64

# %%
 survey_results.loc[survey_results["DevType"] == "Data scientist or machine learning specialist"].count()
# Out:
# ResponseId             498
# MainBranch             498
# Employment             498
# RemoteWork             480
# CodingActivities       479
#                       ...
# TrueFalse_2            299
# TrueFalse_3            299
# SurveyLength           489
# SurveyEase             490
# ConvertedCompYearly    342
# Length: 79, dtype: int64

# %%
 survey_results.loc[survey_results["DevType"] == "Engineer, data"].count()
# Out:
# ResponseId             334
# MainBranch             334
# Employment             334
# RemoteWork             325
# CodingActivities       324
#                       ...
# TrueFalse_2            195
# TrueFalse_3            197
# SurveyLength           324
# SurveyEase             326
# ConvertedCompYearly    217
# Length: 79, dtype: int64

# %%
 survey_results.loc[survey_results["DevType"] == "Data or business analyst"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f669492c05b4> in <module>
# ----> 1 survey_results.loc[survey_results["DevType"] == "Data or business analyst"].count()
#
# NameError: name 'survey_results' is not defined

# %%
survey_results['Accessibility'].value_counts()
# Out:
# None of the above                                                                                                                                                                                           63064
# Prefer not to say                                                                                                                                                                                            1633
# I am blind / have difficulty seeing                                                                                                                                                                           981
# Or, in your own words:                                                                                                                                                                                        579
# ...
